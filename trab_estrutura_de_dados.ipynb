# %% [markdown]
# <a href="https://colab.research.google.com/github/pomppeji/trab-estrutura-de-dados/blob/main/trab_estrutura_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title
import queue
import random
import time

baseDados = {1: ["Suplemento", 50.00, 2], 
             2: ["Xarope", 15.0, 5], 
             3: ["Vitamina C", 16.90, 8], 
             4: ['Colírio', 7.50, 20], 
             5: ['Aguardente', 7.50, 3], 
             6: ['Cotonete', 10.0, 4], 
             7: ['Algodão', 8.20, 7], 
             8: ['Álcool', 8.20, 7], 
             9: ['Soro fisiológico', 15.0, 2], 
             10: ['Esparadrapo', 25.0, 4]}

def Menu():
  print("======== FARMÁCIA POPULAR ======== ")
  print("1 - Listar produtos no estoque")
  print("2 - Inserir produtos no estoque")
  print("3 - Remover produto do estoque")
  print("4 - Registrar item do cliente")
  print("")
  
  opcao = None
  while opcao is None:
    resposta = input("Digite a opção desejada: ")
    if resposta.isnumeric() == True:
      opcao = int(resposta)
    else:
      print("Opção inválida.")

  if opcao == 1:
    listaProduto()

  if opcao == 2:
    insereProduto()
  
  if opcao == 3:
    removeProduto()
  
  if opcao == 4:
    atendeCliente()

def listaProduto():
    print("\n")
    for i in baseDados:
      print(f"Código do produto:{i}", "--", 'Nome:', baseDados[i][0], '----------', 'Preço: R$', baseDados[i][1], '--------', 'Quantidade:', baseDados[i][2],)
    print("\n")

def insereProduto():
    for i in baseDados:
      if baseDados[i][2] == 0:
        novaQtd = int(input(f"Digite a quantidade de {baseDados[i][0]} a ser atualizada:"))
        baseDados[i][2] = novaQtd 

def removeProduto():
    itemRemv = int(input("Digite o código do item a ser removido: "))
    del baseDados[itemRemv]

def ZerarPedido(qtdPedida, filaAtendimento):
    qtdPedida = qtdPedida - qtdPedida
    infoCliente = [nomeCliente, itemPedido, qtdPedida]
    filaAtendimento.put(infoCliente)

def atendeCliente():
    filaAtendimento = queue.Queue(2)

    def ZerarPedido(qtdPedida):
      qtdPedida = qtdPedida - qtdPedida
      infoCliente = [nomeCliente, itemPedido, qtdPedida]
      filaAtendimento.put(infoCliente)

    def PedidoMaiorQueEstoque(qtdPedida, ZerarPedido):
      print(f"{nomeCliente}, quantidade solicitada não atende a quantidade disponível no estoque.")
      print(f"Quantidade disponível: {baseDados[itemPedido][2]}.")
      resposta = input("Gostaria de levar a quantidade disponivel? (S/N): ")

      if (resposta == "S" or resposta == "s"):
        qtdPedida = qtdPedida - qtdPedida
        qtdPedida = baseDados[itemPedido][2] + qtdPedida
        infoCliente = [nomeCliente, itemPedido, qtdPedida]
        baseDados[itemPedido][2] = baseDados[itemPedido][2] - qtdPedida
        filaAtendimento.put(infoCliente)
      elif (resposta == "N" or resposta =="n"):
        ZerarPedido(qtdPedida)

    for i in range(2):
      nomeCliente = input("Digite o nome do cliente: ")
      itemPedido = int(input("Digite o código do item desejado: "))
      qtdPedida = int(input("Insira a quantidade desejada: "))
      
      infoCliente = [nomeCliente, itemPedido, qtdPedida]

      filaAtendimento.put(infoCliente)

      print("--")

    for i in range(filaAtendimento.qsize()):
      nomeCliente, itemPedido, qtdPedida = filaAtendimento.get()

      if (baseDados[itemPedido][2] >= qtdPedida):
        infoCliente = [nomeCliente, itemPedido, qtdPedida]
        baseDados[itemPedido][2] = baseDados[itemPedido][2] - qtdPedida
        filaAtendimento.put(infoCliente)

      elif (qtdPedida > baseDados[itemPedido][2]) and (baseDados[itemPedido][2] > 0):
        PedidoMaiorQueEstoque(qtdPedida, ZerarPedido)

      elif (baseDados[itemPedido][2] == 0):
        print(f"{nomeCliente}, produto solicitado está indisponível no estoque.")
        resposta = input("Gostaria de fazer outro pedido? (S/N): ")

        while True:
          if (resposta == "S" or resposta == "s"):
            itemPedido = int(input("Digite o código do item desejado: "))
            qtdPedida = int(input("Insira a quantidade desejada: "))
                  
            infoCliente = [nomeCliente, itemPedido, qtdPedida]
              
            if (qtdPedida <= baseDados[itemPedido][2]):
              infoCliente = [nomeCliente, itemPedido, qtdPedida]
              baseDados[itemPedido][2] = baseDados[itemPedido][2] - qtdPedida
              filaAtendimento.put(infoCliente)
              break
              
            elif (baseDados[itemPedido][2] == 0):
              print(f"{nomeCliente}, quantidade solicitada está indisponível no estoque.")
              resposta = input("Gostaria de fazer outro pedido? (S/N): ")

            elif (qtdPedida > baseDados[itemPedido][2]) and (baseDados[itemPedido][2] > 0):
              PedidoMaiorQueEstoque(qtdPedida, ZerarPedido)
              break

          if (resposta == "N" or resposta == "n"):
            ZerarPedido(qtdPedida)
            break
    #-- 
    
    
    
    while filaAtendimento.full():
      for i in range(filaAtendimento.qsize()):
        caixa = random.randint(1,3)
        nomeCliente, itemPedido, qtdPedida = filaAtendimento.get()

        if qtdPedida > 0:
          print("")
          print(f"====== CAIXA {caixa} ======")
          print("Dados da compra:")
          print(f"Nome do cliente: {nomeCliente}")
          print(f"Produto pedido: {baseDados[itemPedido][0]}. Quantidade solicitada: {qtdPedida}.")
          valorTotal = qtdPedida * baseDados[itemPedido][1]
          print(f"Total a pagar: R$ {valorTotal:.2f}")
          time.sleep(5) 
          print("--")        
      if filaAtendimento.empty():
        break

sit = True
while sit:
  Menu()
# Out:
# ======== FARMÁCIA POPULAR ========
# 1 - Listar produtos no estoque
# 2 - Inserir produtos no estoque
# 3 - Remover produto do estoque
# 4 - Registrar item do cliente
#
# Digite a opção desejada: 1
#
#
# Código do produto:1 -- Nome: Suplemento ---------- Preço: R$ 50.0 -------- Quantidade: 2
# Código do produto:2 -- Nome: Xarope ---------- Preço: R$ 15.0 -------- Quantidade: 5
# Código do produto:3 -- Nome: Vitamina C ---------- Preço: R$ 16.9 -------- Quantidade: 8
# Código do produto:4 -- Nome: Colírio ---------- Preço: R$ 7.5 -------- Quantidade: 20
# Código do produto:5 -- Nome: Aguardente ---------- Preço: R$ 7.5 -------- Quantidade: 3
# Código do produto:6 -- Nome: Cotonete ---------- Preço: R$ 10.0 -------- Quantidade: 4
# Código do produto:7 -- Nome: Algodão ---------- Preço: R$ 8.2 -------- Quantidade: 7
# Código do produto:8 -- Nome: Álcool ---------- Preço: R$ 8.2 -------- Quantidade: 7
# Código do produto:9 -- Nome: Soro fisiológico ---------- Preço: R$ 15.0 -------- Quantidade: 2
# Código do produto:10 -- Nome: Esparadrapo ---------- Preço: R$ 25.0 -------- Quantidade: 4
#
#
# ======== FARMÁCIA POPULAR ========
# 1 - Listar produtos no estoque
# 2 - Inserir produtos no estoque
# 3 - Remover produto do estoque
# 4 - Registrar item do cliente
#
# Digite a opção desejada: 4
# Digite o nome do cliente: josé
# Digite o código do item desejado: 1
# Insira a quantidade desejada: 2
# --
# Digite o nome do cliente: Maria
# Digite o código do item desejado: 1
# Insira a quantidade desejada: 1
# --
# Maria, produto solicitado está indisponível no estoque.
# Gostaria de fazer outro pedido? (S/N): s
# Digite o código do item desejado: 5
# Insira a quantidade desejada: 6
# Maria, quantidade solicitada não atende a quantidade disponível no estoque.
# Quantidade disponível: 3.
# Gostaria de levar a quantidade disponivel? (S/N): n
#
# ====== CAIXA 1 ======
# Dados da compra:
# Nome do cliente: josé
# Produto pedido: Suplemento. Quantidade solicitada: 2.
# Total a pagar: R$ 100.00
# --
# ======== FARMÁCIA POPULAR ========
# 1 - Listar produtos no estoque
# 2 - Inserir produtos no estoque
# 3 - Remover produto do estoque
# 4 - Registrar item do cliente
#
# Digite a opção desejada: 1
#
#
# Código do produto:1 -- Nome: Suplemento ---------- Preço: R$ 50.0 -------- Quantidade: 0
# Código do produto:2 -- Nome: Xarope ---------- Preço: R$ 15.0 -------- Quantidade: 5
# Código do produto:3 -- Nome: Vitamina C ---------- Preço: R$ 16.9 -------- Quantidade: 8
# Código do produto:4 -- Nome: Colírio ---------- Preço: R$ 7.5 -------- Quantidade: 20
# Código do produto:5 -- Nome: Aguardente ---------- Preço: R$ 7.5 -------- Quantidade: 3
# Código do produto:6 -- Nome: Cotonete ---------- Preço: R$ 10.0 -------- Quantidade: 4
# Código do produto:7 -- Nome: Algodão ---------- Preço: R$ 8.2 -------- Quantidade: 7
# Código do produto:8 -- Nome: Álcool ---------- Preço: R$ 8.2 -------- Quantidade: 7
# Código do produto:9 -- Nome: Soro fisiológico ---------- Preço: R$ 15.0 -------- Quantidade: 2
# Código do produto:10 -- Nome: Esparadrapo ---------- Preço: R$ 25.0 -------- Quantidade: 4
#
#
# ======== FARMÁCIA POPULAR ========
# 1 - Listar produtos no estoque
# 2 - Inserir produtos no estoque
# 3 - Remover produto do estoque
# 4 - Registrar item do cliente
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     723         """
# --> 724         parts = [self.recv(flags, copy=copy, track=track)]
#     725         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7d35828406c3> in <module>()
#     160 sit = True
#     161 while sit:
# --> 162   Menu()
#
# <ipython-input-8-7d35828406c3> in Menu()
#      25   opcao = None
#      26   while opcao is None:
# ---> 27     resposta = input("Digite a opção desejada: ")
#      28     if resposta.isnumeric() == True:
#      29       opcao = int(resposta)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
